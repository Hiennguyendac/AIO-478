# %%
pip install numpy opencv-python

# %%
import cv2
import matplotlib.pyplot as plt

# Đọc ảnh
image_path = '/content/drive/MyDrive/AI/Bai_tap_Support/dataset/2.jpg'
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Hiển thị ảnh gốc
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.show()

# %%
import numpy as np

def gaussian_kernel(size, sigma):
    if size % 2 == 0:
        size = size + 1

    max_point = size // 2
    min_point = -max_point

    K = np.zeros((size, size))
    for x in range(min_point, max_point + 1):
        for y in range(min_point, max_point + 1):
            value = (1/(2*np.pi*sigma**2)) * np.exp(-(x**2 + y**2)/(2*sigma**2))
            K[x - min_point, y - min_point] = value

    return K

# %%
# Áp dụng Gaussian Filter với sigma = 2.5, 5.0, 10.0
sigmas = [2.5, 5.0, 10.0]
for sigma in sigmas:
    kernel = gaussian_kernel(5, sigma)
    img_gaussian = cv2.filter2D(image, -1, kernel)

    # Hiển thị kết quả
    plt.imshow(img_gaussian, cmap='gray')
    plt.title(f'Gaussian Blurred Image with sigma={sigma}')
    plt.show()
